# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#load the first dataset for consideration
raw_inc_df = pd.read_csv("../data/raw/incident_event_log.csv")

# %%
raw_inc_df.sample(n=5)
# Out:
#            number incident_state  active  reassignment_count  reopen_count  \
# 63077  INC0014731            New    True                   0             0
# 43560  INC0009795            New    True                   4             0
# 78371  INC0018607         Closed   False                   0             0
# 41696  INC0009375            New    True                   1             0
# 83828  INC0020088         Active    True                   7             0
#
#        sys_mod_count  made_sla    caller_id       opened_by        opened_at  \
# 63077              0      True   Caller 291   Opened by  17   4/4/2016 09:56
# 43560              8      True  Caller 2931   Opened by  17  22/3/2016 08:48
# 78371              2      True  Caller 5285   Opened by  17  13/4/2016 11:21
# 41696              2      True  Caller 4739  Opened by  390  21/3/2016 10:56
# 83828             12      True  Caller 5287   Opened by  17  17/4/2016 09:40
#
#        sys_created_by   sys_created_at  sys_updated_by   sys_updated_at  \
# 63077               ?                ?  Updated by 908   4/4/2016 09:56
# 43560   Created by 10  22/3/2016 09:00  Updated by 308  29/3/2016 11:40
# 78371               ?                ?  Updated by 908  18/4/2016 12:07
# 41696  Created by 169  21/3/2016 10:58  Updated by 131  22/3/2016 22:14
# 83828               ?                ?  Updated by 510  29/4/2016 16:20
#
#       contact_type      location     category      subcategory    u_symptom  \
# 63077        Phone  Location 135  Category 42  Subcategory 223  Symptom 534
# 43560        Phone  Location 204  Category 37  Subcategory 135  Symptom 118
# 78371        Phone  Location 161  Category 32    Subcategory 9  Symptom 105
# 41696        Phone  Location 204  Category 26  Subcategory 164  Symptom 420
# 83828        Phone  Location 204  Category 23  Subcategory 174  Symptom 491
#
#       cmdb_ci      impact     urgency      priority assignment_group  \
# 63077       ?  2 - Medium  2 - Medium  3 - Moderate         Group 70
# 43560       ?  2 - Medium  2 - Medium  3 - Moderate         Group 70
# 78371       ?  2 - Medium  2 - Medium  3 - Moderate         Group 70
# 41696       ?  2 - Medium  2 - Medium  3 - Moderate                ?
# 83828       ?  2 - Medium  2 - Medium  3 - Moderate         Group 72
#
#         assigned_to  knowledge  u_priority_confirmation         notify  \
# 63077             ?      False                    False  Do Not Notify
# 43560   Resolver 13      False                    False  Do Not Notify
# 78371   Resolver 13      False                     True  Do Not Notify
# 41696   Resolver 57      False                    False  Do Not Notify
# 83828  Resolver 110      False                    False  Do Not Notify
#
#       problem_id rfc vendor caused_by closed_code      resolved_by  \
# 63077          ?   ?      ?         ?      code 6   Resolved by 11
# 43560          ?   ?      ?         ?      code 6   Resolved by 11
# 78371          ?   ?      ?         ?      code 9   Resolved by 11
# 41696          ?   ?      ?         ?      code 6   Resolved by 53
# 83828          ?   ?      ?         ?      code 9  Resolved by 127
#
#            resolved_at        closed_at
# 63077   4/4/2016 10:19   9/4/2016 10:59
# 43560   1/4/2016 12:04   6/4/2016 12:59
# 78371  13/4/2016 11:24  18/4/2016 12:07
# 41696  28/3/2016 16:26   2/4/2016 16:59
# 83828   2/5/2016 11:33   7/5/2016 12:07

# %% [markdown]
# The incident dataset does not have a text field, which doesn't align with our
# learning objective of getting hands on NLP experience. Let's try another dataset.

# %%
#load the second dataset for consideration
raw_cust_df = pd.read_csv("../data/raw/customer_support_tickets.csv")

# %%
raw_cust_df.sample(n=5)
# Out:
#       Ticket ID    Customer Name               Customer Email  Customer Age  \
# 3920       3921     Eugene Brown           csmith@example.org            68
# 7900       7901  Regina Espinoza   swansonrebecca@example.com            53
# 6291       6292     Joseph Smith  daniellejohnson@example.net            27
# 580         581    Rebekah Price          ocarter@example.org            27
# 7651       7652    Ryan Castillo         joelhall@example.org            20
#
#      Customer Gender     Product Purchased Date of Purchase  \
# 3920           Other  Dyson Vacuum Cleaner       2021-07-18
# 7900           Other           Amazon Echo       2020-04-26
# 6291            Male           MacBook Pro       2020-09-05
# 580            Other        Samsung Galaxy       2020-09-07
# 7651          Female             Canon EOS       2021-09-24
#
#                Ticket Type Ticket Subject  \
# 3920  Cancellation request  Display issue
# 7900        Refund request   Battery life
# 6291       Technical issue  Product setup
# 580   Cancellation request   Software bug
# 7651       Product inquiry      Data loss
#
#                                      Ticket Description Ticket Status  \
# 3920  I'm having an issue with the {product_purchase...          Open
# 7900  I'm having an issue with the {product_purchase...          Open
# 6291  I'm having an issue with the {product_purchase...          Open
# 580   I'm having an issue with the {product_purchase...        Closed
# 7651  I'm having an issue with the {product_purchase...          Open
#
#                                    Resolution Ticket Priority Ticket Channel  \
# 3920                                      NaN          Medium   Social media
# 7900                                      NaN        Critical   Social media
# 6291                                      NaN          Medium          Email
# 580   Lay common nature dog stuff staff late.        Critical   Social media
# 7651                                      NaN        Critical          Email
#
#       First Response Time   Time to Resolution  Customer Satisfaction Rating
# 3920                  NaN                  NaN                           NaN
# 7900                  NaN                  NaN                           NaN
# 6291                  NaN                  NaN                           NaN
# 580   2023-06-01 03:37:01  2023-06-01 06:13:01                           2.0
# 7651                  NaN                  NaN                           NaN

# %%
raw_cust_df.isnull().sum() * 100/len(raw_cust_df)
# Out:
# Ticket ID                        0.000000
# Customer Name                    0.000000
# Customer Email                   0.000000
# Customer Age                     0.000000
# Customer Gender                  0.000000
# Product Purchased                0.000000
# Date of Purchase                 0.000000
# Ticket Type                      0.000000
# Ticket Subject                   0.000000
# Ticket Description               0.000000
# Ticket Status                    0.000000
# Resolution                      67.304286
# Ticket Priority                  0.000000
# Ticket Channel                   0.000000
# First Response Time             33.286102
# Time to Resolution              67.304286
# Customer Satisfaction Rating    67.304286
# dtype: float64

# %% [markdown]
# ### High-Level Data Audit:
# - Structured fields: demographics (age, gender), product, priority, channel, type, etc.
# - Semi-structured / unstructured text fields: subject, description, resolution.
# - Target-like fields: time to resolution, satisfaction rating.
# - Many missing values — notably in time-based and satisfaction fields.
# - This dataset is extremely rich for multi-modal modeling — combining structured features + text embeddings.
#
# ### Project Idea 1: Ticket Topic Modeling (BERTopic)
# - Objective: Use BERTopic (or similar) to create meaningful topics from Ticket Description or Ticket Subject.
# - Useful for automated tagging.
# - Could help reduce manual ticket triage.
# - Can visualize trends: which topics are most common, which have higher resolution delays or satisfaction problems.
#
# ### Project Idea 2: Agent Assignment / Routing Model
# - Objective: Predict which agent (or team) should handle the ticket based on early ticket info.
# - Don’t have an agent field right now, but you could simulate this using synthetic labels:
# - Build clusters of tickets using BERTopic
# - Assign each cluster to a hypothetical specialized team
# - Build classification models to route new tickets.
# - **Business value: More efficient routing → faster resolutions → higher satisfaction.**
#
# ### Project Idea 3: Sentiment Analysis Augmentation
# - Objective: Perform sentiment analysis on the Ticket Description field.
# - May correlate highly with satisfaction, resolution time, or escalation likelihood.
# - Could serve as feature enrichment for any of the previous models.

# %%
#load the third dataset for consideration
raw_multi_df = pd.read_csv("../data/raw/aa_dataset-tickets-multi-lang-5-2-50-version.csv")

# %%
#check shape
raw_multi_df.shape
# Out:
# (28587, 16)

# %%
raw_multi_df.sample(n=5)
# Out:
#                                                  subject  \
# 25237         Urgent: Improve Hospital Data Security Now
# 28585  Update Request for SaaS Platform Integration F...
# 15832  Unterstützung benötigt für Datenanalyse in Mic...
# 13014                 Assistance with Financial Products
# 4974   Inquiry Regarding Healthcare Data Security Sol...
#
#                                                     body  \
# 25237  We need to implement strong encryption methods...
# 28585  Requesting an update on the integration featur...
# 15832  Ich benötige Hilfe bei der Integration und Dat...
# 13014  Is it possible to get detailed information on ...
# 4974   Customer Support is reaching out to inquire ab...
#
#                                                   answer     type  \
# 25237  We appreciate the email highlighting the impor...   Change
# 28585  Received your request for updates on the integ...   Change
# 15832  Ich kann Ihnen Rat zur Integration und Datenan...  Request
# 13014  Thank you for reaching out regarding support w...  Request
# 4974   To provide information about healthcare data s...  Request
#
#                       queue priority language  version     tag_1  \
# 25237     Technical Support     high       en      400  Security
# 28585            IT Support     high       en      400   Feature
# 15832  Billing and Payments      low       de      400        IT
# 13014       Product Support   medium       en      400  Feedback
# 4974       Customer Service   medium       en       52  Security
#
#               tag_2          tag_3         tag_4     tag_5  tag_6 tag_7 tag_8
# 25237            IT   Tech Support    Compliance  Training  Alert   NaN   NaN
# 28585            IT   Tech Support           NaN       NaN    NaN   NaN   NaN
# 15832  Tech Support  Documentation      Feedback       NaN    NaN   NaN   NaN
# 13014         Sales             IT  Tech Support       NaN    NaN   NaN   NaN
# 4974             IT       Feedback           NaN       NaN    NaN   NaN   NaN

# %%
raw_multi_df.isnull().sum() * 100/len(raw_multi_df)
# Out:
# subject     13.425683
# body         0.000000
# answer       0.024487
# type         0.000000
# queue        0.000000
# priority     0.000000
# language     0.000000
# version      0.000000
# tag_1        0.000000
# tag_2        0.045475
# tag_3        0.475741
# tag_4       10.697170
# tag_5       49.120229
# tag_6       79.452199
# tag_7       92.863889
# tag_8       98.023577
# dtype: float64

# %%
raw_multi_df["language"].value_counts()
# Out:
# language
# en    16338
# de    12249
# Name: count, dtype: int64

# %%
raw_multi_df["queue"].value_counts()
# Out:
# queue
# Technical Support                  8362
# Product Support                    5252
# Customer Service                   4268
# IT Support                         3433
# Billing and Payments               2788
# Returns and Exchanges              1437
# Service Outages and Maintenance    1148
# Sales and Pre-Sales                 918
# Human Resources                     576
# General Inquiry                     405
# Name: count, dtype: int64

# %% [markdown]
# ### High-Level Audit of Dataset
# - Customer ticket (subject, body)
# - Agent response (answer)
# - Structured metadata (queue, priority, type, tags, language)
# - Multilingual support (en, de)
# - Tagged labels (tags fields: tag_1 through tag_8)
#
# ### Project Idea 1: Ticket Routing / Department Classification (Text Classification)
# - Objective: Build a model that classifies the ticket into the correct queue based on subject + body.
# - Use Case:
#      - Automate ticket triage.
#      - Reduce agent workload.
#      - Speed up first response times.
#
# ### Project Idea 2: Priority Prediction
# - Objective: Predict priority based on ticket content and metadata.
# - Use Case:
#      - Auto-triage incoming tickets.
#      - Proactively identify urgent issues.
#
# ### Project Idea 3: Multi-label Tag Prediction
# - Objective: Predict tag_1 through tag_8 fields based on subject and body.
# - Use Case:
#      - Suggest tags to agents as they draft tickets.
#      - Analyze most common issues.
